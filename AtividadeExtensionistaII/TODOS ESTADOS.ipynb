# %%
# importando a biblioteca pandas 
import pandas as pd

# %%
# abrindo o dataset
df = pd.read_csv('acidentes2021_todas_causas_tipos.csv', sep=';' , encoding='latin-1')
pd.set_option('display.max_columns', None)

# %%
# dimensões do dataset
df.shape
# Out:
# (449017, 37)

# %%
# colunas do dataset
df.columns
# Out:
# Index(['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br',
#        'km', 'municipio', 'causa_principal', 'causa_acidente',
#        'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista',
#        'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca',
#        'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade',
#        'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos',
#        'latitude', 'longitude', 'regional', 'delegacia', 'uop'],
#       dtype='object')

# %%
# amostras das primeiras linhas 
df.head()
# Out:
#          id     pesid data_inversa   dia_semana   horario  uf     br     km  \
# 0  331693.0  739775.0   2021-01-01  sexta-feira  00:02:00  SC  101.0  314,9
# 1  331693.0  739774.0   2021-01-01  sexta-feira  00:02:00  SC  101.0  314,9
# 2  331693.0  738219.0   2021-01-01  sexta-feira  00:02:00  SC  101.0  314,9
# 3  331693.0  739775.0   2021-01-01  sexta-feira  00:02:00  SC  101.0  314,9
# 4  331693.0  739774.0   2021-01-01  sexta-feira  00:02:00  SC  101.0  314,9
#
#   municipio causa_principal                    causa_acidente  \
# 0    LAGUNA             Sim  Ingestão de álcool pelo condutor
# 1    LAGUNA             Sim  Ingestão de álcool pelo condutor
# 2    LAGUNA             Sim  Ingestão de álcool pelo condutor
# 3    LAGUNA             Sim  Ingestão de álcool pelo condutor
# 4    LAGUNA             Sim  Ingestão de álcool pelo condutor
#
#    ordem_tipo_acidente       tipo_acidente classificacao_acidente  \
# 0                    3         Capotamento    Com Vítimas Feridas
# 1                    3         Capotamento    Com Vítimas Feridas
# 2                    3         Capotamento    Com Vítimas Feridas
# 3                    2  Colisão com objeto    Com Vítimas Feridas
# 4                    2  Colisão com objeto    Com Vítimas Feridas
#
#       fase_dia sentido_via condicao_metereologica tipo_pista tracado_via  \
# 0  Plena Noite   Crescente                Nublado      Dupla        Reta
# 1  Plena Noite   Crescente                Nublado      Dupla        Reta
# 2  Plena Noite   Crescente                Nublado      Dupla        Reta
# 3  Plena Noite   Crescente                Nublado      Dupla        Reta
# 4  Plena Noite   Crescente                Nublado      Dupla        Reta
#
#   uso_solo  id_veiculo tipo_veiculo  \
# 0      Não      595104    Automóvel
# 1      Não      595103    Automóvel
# 2      Não      595103    Automóvel
# 3      Não      595104    Automóvel
# 4      Não      595103    Automóvel
#
#                                              marca  ano_fabricacao_veiculo  \
# 0               FIAT/UNO VIVACE 1.0/UNO VIVACE 1.0                  2010.0
# 1  I/RENAULT CLIO CAM 10H3P/RENAULT CLIO CAM 10H3P                  2010.0
# 2  I/RENAULT CLIO CAM 10H3P/RENAULT CLIO CAM 10H3P                  2010.0
# 3               FIAT/UNO VIVACE 1.0/UNO VIVACE 1.0                  2010.0
# 4  I/RENAULT CLIO CAM 10H3P/RENAULT CLIO CAM 10H3P                  2010.0
#
#   tipo_envolvido estado_fisico  idade       sexo  ilesos  feridos_leves  \
# 0       Condutor         Ileso   35.0  Masculino       1              0
# 1     Passageiro  Lesões Leves   22.0   Feminino       0              1
# 2       Condutor         Ileso   27.0  Masculino       1              0
# 3       Condutor         Ileso   35.0  Masculino       1              0
# 4     Passageiro  Lesões Leves   22.0   Feminino       0              1
#
#    feridos_graves  mortos   latitude  longitude regional delegacia    uop
# 0               0       0 -28.430294 -48.849251    SR-SC     DEL02  UOP01
# 1               0       0 -28.430294 -48.849251    SR-SC     DEL02  UOP01
# 2               0       0 -28.430294 -48.849251    SR-SC     DEL02  UOP01
# 3               0       0 -28.430294 -48.849251    SR-SC     DEL02  UOP01
# 4               0       0 -28.430294 -48.849251    SR-SC     DEL02  UOP01

# %%
# amostras das últimas linhas
df.tail()
# Out:
#               id     pesid data_inversa    dia_semana   horario  uf     br  \
# 449012  461175.0  996488.0   2021-11-14       domingo  07:00:00  GO   70.0
# 449013  461534.0       NaN   2021-11-11  quinta-feira  00:10:00  BA  116.0
# 449014  461534.0  997402.0   2021-11-11  quinta-feira  00:10:00  BA  116.0
# 449015  461534.0  997401.0   2021-11-11  quinta-feira  00:10:00  BA  116.0
# 449016  461534.0  997400.0   2021-11-11  quinta-feira  00:10:00  BA  116.0
#
#           km              municipio causa_principal  \
# 449012  18,3  AGUAS LINDAS DE GOIAS             Sim
# 449013   531                 ITATIM             Sim
# 449014   531                 ITATIM             Sim
# 449015   531                 ITATIM             Sim
# 449016   531                 ITATIM             Sim
#
#                      causa_acidente  ordem_tipo_acidente  \
# 449012  Manobra de mudança de faixa                    1
# 449013            Condutor Dormindo                    1
# 449014            Condutor Dormindo                    1
# 449015            Condutor Dormindo                    1
# 449016            Condutor Dormindo                    1
#
#                          tipo_acidente classificacao_acidente     fase_dia  \
# 449012                 Colisão frontal    Com Vítimas Feridas    Pleno dia
# 449013  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
# 449014  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
# 449015  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
# 449016  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
#
#         sentido_via condicao_metereologica tipo_pista        tracado_via  \
# 449012  Decrescente              Céu Claro    Simples  Desvio Temporário
# 449013  Decrescente              Céu Claro    Simples               Reta
# 449014  Decrescente              Céu Claro    Simples               Reta
# 449015  Decrescente              Céu Claro    Simples               Reta
# 449016  Decrescente              Céu Claro    Simples               Reta
#
#        uso_solo  id_veiculo     tipo_veiculo  \
# 449012      Não      805871        Automóvel
# 449013      Sim      806595      Semireboque
# 449014      Sim      806594  Caminhão-trator
# 449015      Sim      806593         Caminhão
# 449016      Sim      806592        Automóvel
#
#                                      marca  ano_fabricacao_veiculo  \
# 449012      FIAT/UNO MILLE EX/UNO MILLE EX                  2000.0
# 449013        SR/RANDON SR FG/RANDON SR FG                  2001.0
# 449014   VOLVO/FH12 380 4X2T/FH12 380 4X2T                  2001.0
# 449015        M.BENZ/ATEGO 2426/ATEGO 2426                  2017.0
# 449016  FIAT/PALIO ELX FLEX/PALIO ELX FLEX                  2009.0
#
#        tipo_envolvido  estado_fisico  idade           sexo  ilesos  \
# 449012       Condutor  Não Informado    NaN  Não Informado       0
# 449013  Não Informado  Não Informado    NaN  Não Informado       0
# 449014       Condutor          Ileso   25.0      Masculino       1
# 449015       Condutor          Ileso   36.0      Masculino       1
# 449016       Condutor   Lesões Leves   54.0       Feminino       0
#
#         feridos_leves  feridos_graves  mortos   latitude  longitude regional  \
# 449012              0               0       0 -15.744741 -48.355934    SR-DF
# 449013              0               0       0 -12.745962 -39.791878    SR-BA
# 449014              0               0       0 -12.745962 -39.791878    SR-BA
# 449015              0               0       0 -12.745962 -39.791878    SR-BA
# 449016              1               0       0 -12.745962 -39.791878    SR-BA
#
#        delegacia    uop
# 449012     DEL01  UOP03
# 449013     DEL03  UOP02
# 449014     DEL03  UOP02
# 449015     DEL03  UOP02
# 449016     DEL03  UOP02

# %%
# ordenando as datas
df.sort_values('data_inversa')
# Out:
#               id     pesid data_inversa   dia_semana   horario  uf     br  \
# 0       331693.0  739775.0   2021-01-01  sexta-feira  00:02:00  SC  101.0
# 777     331899.0  738605.0   2021-01-01  sexta-feira  18:30:00  RO  364.0
# 776     331899.0  738606.0   2021-01-01  sexta-feira  18:30:00  RO  364.0
# 775     331899.0  738612.0   2021-01-01  sexta-feira  18:30:00  RO  364.0
# 774     331899.0  738601.0   2021-01-01  sexta-feira  18:30:00  RO  364.0
# ...          ...       ...          ...          ...       ...  ..    ...
# 437473  404997.0  908519.0   2021-12-31  sexta-feira  04:00:00  BA  349.0
# 437472  404997.0  908520.0   2021-12-31  sexta-feira  04:00:00  BA  349.0
# 437471  404997.0  906317.0   2021-12-31  sexta-feira  04:00:00  BA  349.0
# 437485  404997.0  908453.0   2021-12-31  sexta-feira  04:00:00  BA  349.0
# 437088  404997.0  908328.0   2021-12-31  sexta-feira  04:00:00  BA  349.0
#
#             km        municipio causa_principal  \
# 0        314,9           LAGUNA             Sim
# 777        615  ITAPUA DO OESTE             Sim
# 776        615  ITAPUA DO OESTE             Sim
# 775        615  ITAPUA DO OESTE             Sim
# 774        615  ITAPUA DO OESTE             Sim
# ...        ...              ...             ...
# 437473  1019,2       CORRENTINA             Não
# 437472  1019,2       CORRENTINA             Não
# 437471  1019,2       CORRENTINA             Não
# 437485  1019,2       CORRENTINA             Não
# 437088  1019,2       CORRENTINA             Não
#
#                                   causa_acidente  ordem_tipo_acidente  \
# 0               Ingestão de álcool pelo condutor                    3
# 777     Reação tardia ou ineficiente do condutor                    1
# 776     Reação tardia ou ineficiente do condutor                    1
# 775     Reação tardia ou ineficiente do condutor                    2
# 774     Reação tardia ou ineficiente do condutor                    2
# ...                                          ...                  ...
# 437473            Ausência de reação do condutor                    2
# 437472            Ausência de reação do condutor                    2
# 437471                    Mal súbito do condutor                    1
# 437485            Ausência de reação do condutor                    2
# 437088                                     Chuva                    2
#
#                     tipo_acidente classificacao_acidente     fase_dia  \
# 0                     Capotamento    Com Vítimas Feridas  Plena Noite
# 777              Colisão traseira            Sem Vítimas  Plena Noite
# 776              Colisão traseira            Sem Vítimas  Plena Noite
# 775     Saída de leito carroçável            Sem Vítimas  Plena Noite
# 774     Saída de leito carroçável            Sem Vítimas  Plena Noite
# ...                           ...                    ...          ...
# 437473  Saída de leito carroçável     Com Vítimas Fatais  Plena Noite
# 437472  Saída de leito carroçável     Com Vítimas Fatais  Plena Noite
# 437471         Colisão com objeto     Com Vítimas Fatais  Plena Noite
# 437485  Saída de leito carroçável     Com Vítimas Fatais  Plena Noite
# 437088  Saída de leito carroçável     Com Vítimas Fatais  Plena Noite
#
#         sentido_via condicao_metereologica tipo_pista tracado_via uso_solo  \
# 0         Crescente                Nublado      Dupla        Reta      Não
# 777       Crescente              Céu Claro    Simples        Reta      Não
# 776       Crescente              Céu Claro    Simples        Reta      Não
# 775       Crescente              Céu Claro    Simples        Reta      Não
# 774       Crescente              Céu Claro    Simples        Reta      Não
# ...             ...                    ...        ...         ...      ...
# 437473  Decrescente                  Chuva    Simples        Reta      Não
# 437472  Decrescente                  Chuva    Simples        Reta      Não
# 437471  Decrescente                  Chuva    Simples        Reta      Não
# 437485  Decrescente                  Chuva    Simples        Reta      Não
# 437088  Decrescente                  Chuva    Simples        Reta      Não
#
#         id_veiculo tipo_veiculo                                      marca  \
# 0           595104    Automóvel         FIAT/UNO VIVACE 1.0/UNO VIVACE 1.0
# 777         595409    Automóvel    CHEVROLET/PRISMA 1.4L LT/PRISMA 1.4L LT
# 776         595409    Automóvel    CHEVROLET/PRISMA 1.4L LT/PRISMA 1.4L LT
# 775         595410  Motocicleta        HONDA/XR 250 TORNADO/XR 250 TORNADO
# 774         595409    Automóvel    CHEVROLET/PRISMA 1.4L LT/PRISMA 1.4L LT
# ...            ...          ...                                        ...
# 437473      734075       Ônibus  MBENZ/MPOLO PARADISO DD/MPOLO PARADISO DD
# 437472      734075       Ônibus  MBENZ/MPOLO PARADISO DD/MPOLO PARADISO DD
# 437471      734076       Ônibus           M.BENZ/O 400 RSD PL/O 400 RSD PL
# 437485      734075       Ônibus  MBENZ/MPOLO PARADISO DD/MPOLO PARADISO DD
# 437088      734075       Ônibus  MBENZ/MPOLO PARADISO DD/MPOLO PARADISO DD
#
#         ano_fabricacao_veiculo tipo_envolvido  estado_fisico  idade  \
# 0                       2010.0       Condutor          Ileso   35.0
# 777                     2011.0     Passageiro          Ileso   15.0
# 776                     2011.0     Passageiro          Ileso   32.0
# 775                     2002.0       Condutor  Não Informado    NaN
# 774                     2011.0       Condutor          Ileso   30.0
# ...                        ...            ...            ...    ...
# 437473                  2013.0     Passageiro          Ileso   35.0
# 437472                  2013.0     Passageiro          Ileso    2.0
# 437471                  1997.0       Condutor          Ileso   28.0
# 437485                  2013.0     Passageiro   Lesões Leves   31.0
# 437088                  2013.0     Passageiro   Lesões Leves    8.0
#
#                  sexo  ilesos  feridos_leves  feridos_graves  mortos  \
# 0           Masculino       1              0               0       0
# 777          Feminino       1              0               0       0
# 776         Masculino       1              0               0       0
# 775     Não Informado       0              0               0       0
# 774         Masculino       1              0               0       0
# ...               ...     ...            ...             ...     ...
# 437473      Masculino       1              0               0       0
# 437472       Feminino       1              0               0       0
# 437471      Masculino       1              0               0       0
# 437485      Masculino       0              1               0       0
# 437088       Feminino       0              1               0       0
#
#          latitude  longitude regional delegacia    uop
# 0      -28.430294 -48.849251    SR-SC     DEL02  UOP01
# 777     -9.121691 -63.258770    SR-RO     DEL03  UOP03
# 776     -9.121691 -63.258770    SR-RO     DEL03  UOP03
# 775     -9.121691 -63.258770    SR-RO     DEL03  UOP03
# 774     -9.121691 -63.258770    SR-RO     DEL03  UOP03
# ...           ...        ...      ...       ...    ...
# 437473 -13.650582 -45.696439    SR-BA     DEL10  UOP01
# 437472 -13.650582 -45.696439    SR-BA     DEL10  UOP01
# 437471 -13.650582 -45.696439    SR-BA     DEL10  UOP01
# 437485 -13.650582 -45.696439    SR-BA     DEL10  UOP01
# 437088 -13.650582 -45.696439    SR-BA     DEL10  UOP01
#
# [449017 rows x 37 columns]

# %%
# valores ausentes
ausentes = df.isnull().sum()

# %%
ausentes.sort_values(ascending=False)
# Out:
# idade                     89471
# pesid                     39871
# ano_fabricacao_veiculo    26098
# marca                     20933
# br                         1148
# km                         1148
# id                            0
# ilesos                        0
# tipo_envolvido                0
# estado_fisico                 0
# sexo                          0
# feridos_leves                 0
# id_veiculo                    0
# feridos_graves                0
# mortos                        0
# latitude                      0
# longitude                     0
# regional                      0
# delegacia                     0
# tipo_veiculo                  0
# tracado_via                   0
# uso_solo                      0
# tipo_pista                    0
# condicao_metereologica        0
# sentido_via                   0
# fase_dia                      0
# classificacao_acidente        0
# tipo_acidente                 0
# ordem_tipo_acidente           0
# causa_acidente                0
# causa_principal               0
# municipio                     0
# uf                            0
# horario                       0
# dia_semana                    0
# data_inversa                  0
# uop                           0
# dtype: int64

# %%
# total de acidentes
acidentes = df['id'].count()
print(f"Total de acidentes em 2021:",acidentes)
# Out:
# Total de acidentes em 2021: 449017

# %%
# valores estatísticos básicos
df.describe()
#count -> total registros
#mean -> média
#std -> desvio padrão
#min -> valor mínimo encontrado
#25% 
#50% -> pode se dizer a mediana
#75%
#max -> valor máximo encontrado
# Out:
#                   id          pesid             br  ordem_tipo_acidente  \
# count  449017.000000  409146.000000  447869.000000        449017.000000
# mean   370768.841772  827537.877271     214.080874             1.714434
# std     22263.414753   50198.186136     129.089115             1.124477
# min    331693.000000  738204.000000      10.000000             1.000000
# 25%    352086.000000  784964.000000     101.000000             1.000000
# 50%    370969.000000  827775.500000     163.000000             1.000000
# 75%    389182.000000  869827.000000     343.000000             2.000000
# max    461534.000000  997402.000000     495.000000            15.000000
#
#           id_veiculo  ano_fabricacao_veiculo          idade         ilesos  \
# count  449017.000000           422919.000000  359546.000000  449017.000000
# mean   669100.876893             2010.889121      39.077909       0.352082
# std     41894.935669                7.657274      42.743404       0.477620
# min    595095.000000             1900.000000       0.000000       0.000000
# 25%    633503.000000             2008.000000      27.000000       0.000000
# 50%    669804.000000             2012.000000      37.000000       0.000000
# 75%    704367.000000             2017.000000      48.000000       1.000000
# max    806595.000000             2021.000000    2020.000000       1.000000
#
#        feridos_leves  feridos_graves         mortos       latitude  \
# count  449017.000000   449017.000000  449017.000000  449017.000000
# mean        0.308180        0.119316       0.046591     -17.856646
# std         0.461742        0.324161       0.210761       7.895898
# min         0.000000        0.000000       0.000000     -33.689819
# 25%         0.000000        0.000000       0.000000     -23.618093
# 50%         0.000000        0.000000       0.000000     -19.776540
# 75%         1.000000        0.000000       0.000000     -11.435201
# max         1.000000        1.000000       1.000000       4.461419
#
#            longitude
# count  449017.000000
# mean      -47.141167
# std         6.406649
# min       -72.119380
# 25%       -51.115413
# 50%       -47.817140
# 75%       -43.023224
# max       -34.828232

# %%
# soma do total de ilesos
ilesos = df['ilesos'].sum()
print(f"Total de ilesos:",ilesos)
# Out:
# Total de ilesos: 158091

# %%
# soma do total de feridos leves 
feridosleves = df['feridos_leves'].sum()
print(f"Total de feridos leves:",feridosleves)
# Out:
# Total de feridos leves: 138378

# %%
# soma do total de feridos graves 
feridosgraves = df['feridos_graves'].sum()
print(f"Total de feridos graves:",feridosgraves)
# Out:
# Total de feridos graves: 53575

# %%
# soma do total de mortos 
mortos = df['mortos'].sum()
print(f"Total de mortos:",mortos)
# Out:
# Total de mortos: 20920

# %%
# agrupando acidentes por causa
acidente = df.groupby(['causa_acidente']).size().sort_values(ascending=False)
principais_causas = acidente.head(10) # 10 primeiras
principais_causas
# Out:
# causa_acidente
# Velocidade Incompatível                                      55869
# Reação tardia ou ineficiente do condutor                     50576
# Condutor deixou de manter distância do veículo da frente     35819
# Ausência de reação do condutor                               35231
# Acessar a via sem observar a presença dos outros veículos    27620
# Ingestão de álcool pelo condutor                             25264
# Manobra de mudança de faixa                                  25261
# Transitar na contramão                                       15076
# Ultrapassagem Indevida                                       14284
# Chuva                                                        13955
# dtype: int64

# %%
# gráfico principais causas de acidente
import matplotlib.pyplot as plt
principais_causas.plot(kind='bar', color='red')
plt.xlabel('Causa do Acidente')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Principais Causas de Acidentes (Ranking 1ª a 10ª)')
plt.show()

# %%
# filtrando registros por estado
estado = df['uf'].value_counts()
estado
# Out:
# MG    60684
# PR    42176
# SC    37913
# SP    33578
# RS    29710
# GO    27880
# BA    26329
# RJ    25184
# MS    17644
# MT    17589
# PE    17519
# RO    16017
# PA    12553
# ES    11454
# PI    11336
# PB    11328
# CE    10654
# MA     9789
# DF     6502
# RN     6012
# TO     5661
# SE     2785
# AL     2661
# RR     2009
# AC     1443
# AM     1383
# AP     1224
# Name: uf, dtype: int64

# %%
# gráfico acidentes por estado
import matplotlib.pyplot as plt
estado.plot(kind='bar', color='red')
plt.xlabel('Estado')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Estado')
plt.show()

# %%
# agrupando os dados referente as rodovias
qual_rodovia = df.groupby(by='br').sum()
qual_rodovia
# Out:
#                  id         pesid  ordem_tipo_acidente   id_veiculo  \
# br
# 10.0   1.609728e+09  3.254445e+09                 7765   2904179923
# 20.0   2.305991e+09  4.878218e+09                 9382   4159618405
# 30.0   1.867827e+07  3.463795e+07                   56     33723703
# 40.0   8.307723e+09  1.741145e+10                38554  14990049061
# 50.0   2.120800e+09  4.372873e+09                10653   3823261137
# ...             ...           ...                  ...          ...
# 484.0  4.090138e+06  9.125052e+06                   11      7382089
# 487.0  9.779034e+07  2.000883e+08                  422    176455585
# 488.0  5.160635e+07  1.152274e+08                  193     93233898
# 493.0  5.270716e+08  1.146063e+09                 2246    951273942
# 495.0  2.110038e+07  4.707459e+07                   69     38083324
#
#        ano_fabricacao_veiculo     idade  ilesos  feridos_leves  \
# br
# 10.0                7935485.0  116157.0    1501            854
# 20.0               11726570.0  194482.0    2199           1884
# 30.0                  96588.0     678.0      18             14
# 40.0               42907865.0  714403.0    7826           7804
# 50.0               11172988.0  179388.0    1436           2472
# ...                       ...       ...     ...            ...
# 484.0                 14074.0     592.0       0              8
# 487.0                428096.0    8655.0      70             70
# 488.0                247458.0    5095.0      76             41
# 493.0               2599331.0   52525.0     565            526
# 495.0                 86526.0    2100.0      25             20
#
#        feridos_graves  mortos       latitude     longitude
# br
# 10.0              760     302  -19373.481847 -2.036858e+05
# 20.0              961     361  -67983.245498 -2.749699e+05
# 30.0                4       0    -731.891762 -2.115730e+03
# 40.0             2755     862 -438976.228358 -1.009310e+06
# 50.0              768     229 -107513.514636 -2.786580e+05
# ...               ...     ...            ...           ...
# 484.0               2       1    -220.461842 -4.515138e+02
# 487.0              49      13   -6224.023965 -1.398998e+04
# 488.0              10       0   -3131.307246 -6.198417e+03
# 493.0             142      46  -32266.611223 -6.149175e+04
# 495.0               5       1   -1276.828646 -2.454642e+03
#
# [113 rows x 12 columns]

# %%
# soma de acidentes por rodovia (Ranking)
br = df['br'].value_counts()
br_dez_mais = br.head(10)
br_dez_mais
# Out:
# 116.0    61058
# 101.0    59684
# 40.0     22477
# 364.0    21345
# 381.0    21219
# 163.0    20372
# 153.0    20078
# 230.0    12576
# 262.0    11995
# 277.0    11001
# Name: br, dtype: int64

# %%
# gráfico acidentes por rodovia 
import matplotlib.pyplot as plt
br_dez_mais.plot(kind='bar', color='red')
plt.xlabel('Rodovia')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Rodovia (Ranking 1ª a 10ª)')
plt.show()

# %%
# soma de óbitos por rodovia (Ranking)
obitos_rodovia = qual_rodovia.groupby(by='br').sum()['mortos']
ordem_obitos = obitos_rodovia.sort_values(ascending=False)
dezmais = ordem_obitos.head(10)
dezmais
# Out:
# br
# 116.0    2222
# 101.0    2080
# 153.0    1113
# 230.0     866
# 163.0     864
# 40.0      862
# 364.0     815
# 316.0     700
# 262.0     635
# 222.0     626
# Name: mortos, dtype: int64

# %%
# gráfico mortos por rodovia 
import matplotlib.pyplot as plt
dezmais.plot(kind='bar', color='red')
plt.xlabel('Rodovia')
plt.ylabel('Quantidade de Mortos')
plt.title('Mortos x Rodovia (Ranking 1ª a 10ª)')
plt.show()

# %%
# agrupando os dados referente aos estados
qual_estado = df.groupby(by='uf').sum()
qual_estado
# Out:
#               id         pesid          br  ordem_tipo_acidente   id_veiculo  \
# uf
# AC  5.299380e+08  1.155228e+09    512010.0                 2209    956053532
# AL  9.863701e+08  2.011118e+09    559823.0                 3759   1780138422
# AM  5.079548e+08  1.014829e+09    281911.0                 2341    915655561
# AP  4.536116e+08  1.005151e+09    220212.0                 1877    818692135
# BA  9.756098e+09  1.903187e+10   5172352.0                55505  17607488808
# CE  3.953043e+09  8.351484e+09   1532786.0                18850   7134600547
# DF  2.393821e+09  5.263324e+09    350159.0                10388   4317026612
# ES  4.237869e+09  8.890624e+09   1826482.0                16501   7647668494
# GO  1.038591e+10  2.074336e+10   3652797.0                49855  18734830350
# MA  3.639052e+09  7.472181e+09   1556229.0                16208   6568391671
# MG  2.253803e+10  4.486222e+10  13419490.0               105348  40671629147
# MS  6.530175e+09  1.221218e+10   3623061.0                32941  11785706761
# MT  6.510341e+09  1.120895e+10   3549418.0                28754  11751011392
# PA  4.642568e+09  9.546302e+09   2680344.0                23810   8372647333
# PB  4.194516e+09  9.086836e+09   2263886.0                20121   7569089917
# PE  6.534982e+09  1.405096e+10   4031729.0                33752  11792065215
# PI  4.249926e+09  8.770544e+09   3124223.0                20270   7674691341
# PR  1.560915e+10  3.171783e+10  12787890.0                68912  28168913053
# RJ  9.305977e+09  1.992219e+10   3927674.0                37938  16792014040
# RN  2.229897e+09  4.857211e+09   1355237.0                 8964   4023653345
# RO  5.946816e+09  1.190779e+10   5662746.0                28636  10734125884
# RR  7.511726e+08  1.618860e+09    436262.0                 3116   1356088305
# RS  1.099545e+10  2.282990e+10   8656846.0                47246  19842301779
# SC  1.404166e+10  2.943400e+10   8114133.0                58833  25342712762
# SE  1.025476e+09  2.110216e+09    426772.0                 4529   1849786094
# SP  1.245081e+10  2.576156e+10   5218462.0                59577  22475618716
# TO  2.080905e+09  3.747080e+09    937253.0                 9570   3755067224
#
#     ano_fabricacao_veiculo      idade  ilesos  feridos_leves  feridos_graves  \
# uf
# AC               2690152.0    69322.0     494            539             238
# AL               4894595.0    86830.0     818            754             463
# AM               2539764.0    36488.0     390            472             168
# AP               2268583.0    40880.0     372            565             156
# BA              50233692.0   805398.0    9401           7390            2794
# CE              19641266.0   344239.0    3586           3137            1628
# DF              12551701.0   216357.0    3091           2120             553
# ES              21007938.0   392075.0    4006           3429            1947
# GO              54047867.0   841542.0    9192           8866            3364
# MA              18182225.0   298219.0    3122           2819            1386
# MG             116709305.0  1879243.0   18528          19874            7112
# MS              33328798.0   514359.0    5510           5047            2253
# MT              34089357.0   474301.0    5576           4253            1790
# PA              23148210.0   358625.0    3991           3425            1583
# PB              19837049.0   356937.0    3755           3492            1874
# PE              32328532.0   555228.0    5136           4682            3804
# PI              20589383.0   340574.0    3410           3048            1803
# PR              80879760.0  1327907.0   15692          12770            4610
# RJ              46825468.0   859925.0   10929           8621            2160
# RN              10920707.0   209166.0    2132           2191             802
# RO              30609591.0   521637.0    5792           4558            1877
# RR               3763081.0    59374.0     850            588             229
# RS              57696219.0   957697.0   11447           9759            2940
# SC              72446886.0  1207669.0   14287          12833            4265
# SE               5179635.0    85710.0     962            800             365
# SP              63189286.0  1053912.0   13868          11056            2716
# TO              10844166.0   156692.0    1754           1290             695
#
#     mortos      latitude     longitude
# uf
# AC      57 -1.443979e+04 -9.805787e+04
# AL     194 -2.512686e+04 -9.660181e+04
# AM      58 -5.372309e+03 -8.426100e+04
# AP      30  1.634546e+03 -6.279127e+04
# BA    1750 -3.491446e+05 -1.065794e+06
# CE     611 -4.419972e+04 -4.141673e+05
# DF     128 -1.027556e+05 -3.118895e+05
# ES     325 -2.298748e+05 -4.637408e+05
# GO    1511 -4.581499e+05 -1.370771e+06
# MA     738 -4.692053e+04 -4.470084e+05
# MG    2745 -1.193783e+06 -2.711221e+06
# MS     764 -3.693684e+05 -9.596506e+05
# MT     809 -2.505138e+05 -9.778751e+05
# PA    1134 -4.079292e+04 -6.230541e+05
# PB     504 -8.055713e+04 -4.049640e+05
# PE    1290 -1.452629e+05 -6.351128e+05
# PI    1006 -7.368382e+04 -4.854386e+05
# PR    1847 -1.051871e+06 -2.144848e+06
# RJ     775 -5.674542e+05 -1.086006e+06
# RN     275 -3.460378e+04 -2.169414e+05
# RO     478 -1.650040e+05 -1.002376e+06
# RR     116  5.111359e+03 -1.219948e+05
# RS    1079 -8.778843e+05 -1.552820e+06
# SC    1242 -1.031337e+06 -1.880660e+06
# SE     160 -3.022992e+04 -1.037629e+05
# SP     974 -7.859616e+05 -1.570769e+06
# TO     320 -5.039116e+04 -2.746074e+05

# %%
# soma de óbitos por estado
obitos = qual_estado.groupby(by='uf').sum()['mortos']
obitos
# Out:
# uf
# AC      57
# AL     194
# AM      58
# AP      30
# BA    1750
# CE     611
# DF     128
# ES     325
# GO    1511
# MA     738
# MG    2745
# MS     764
# MT     809
# PA    1134
# PB     504
# PE    1290
# PI    1006
# PR    1847
# RJ     775
# RN     275
# RO     478
# RR     116
# RS    1079
# SC    1242
# SE     160
# SP     974
# TO     320
# Name: mortos, dtype: int64

# %%
# ordenando do maior para o menor mortos por estado
mortos_ordem = obitos.sort_values(ascending=False)
mortos_ordem
# Out:
# uf
# MG    2745
# PR    1847
# BA    1750
# GO    1511
# PE    1290
# SC    1242
# PA    1134
# RS    1079
# PI    1006
# SP     974
# MT     809
# RJ     775
# MS     764
# MA     738
# CE     611
# PB     504
# RO     478
# ES     325
# TO     320
# RN     275
# AL     194
# SE     160
# DF     128
# RR     116
# AM      58
# AC      57
# AP      30
# Name: mortos, dtype: int64

# %%
# gráfico mortos por estado
import matplotlib.pyplot as plt
mortos_ordem.plot(kind='bar', color='red')
plt.xlabel('Estado')
plt.ylabel('Quantidade de Mortos')
plt.title('Mortos x Estado')
plt.show()

# %%
sexo = df['sexo'].value_counts()
sexo
# Out:
# Masculino        280628
# Feminino          89188
# Não Informado     78053
# Ignorado           1148
# Name: sexo, dtype: int64

# %%
# gráfico do percentual de acidentes por sexo
plt.figure(figsize=(7, 5))
sexo.plot.pie(fontsize=14, autopct='%0.1f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Sexo', pad=10, fontsize=15)
plt.legend(['Masculino','Feminino','Não Informado','Ignorado'],loc='upper right', bbox_to_anchor=(1.3,1) )
plt.ylabel('')
plt.show()

# %%
# agrupando óbitos por sexo
mortos_por_sexo = df.groupby(by='sexo').sum()['mortos']
mortos_por_sexo
sexo_mortos = mortos_por_sexo.sort_values(ascending=False)
sexo_mortos
# Out:
# sexo
# Masculino        16545
# Feminino          4318
# Ignorado            57
# Não Informado        0
# Name: mortos, dtype: int64

# %%
# gráfico do percentual de mortos por sexo
plt.figure(figsize=(7, 5))
sexo_mortos.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Mortos por Sexo', pad=10, fontsize=15)
plt.legend(['Masculino','Feminino'],loc='upper right', bbox_to_anchor=(1.1,1) )
plt.ylabel('')
plt.show()

# %%
# filtrando acidentes por classificação
class_acidente = df['classificacao_acidente'].value_counts()
class_acidente
# Out:
# Com Vítimas Feridas    321700
# Com Vítimas Fatais      76215
# Sem Vítimas             51102
# Name: classificacao_acidente, dtype: int64

# %%
# gráfico do percentual de acidentes por classificação
plt.figure(figsize=(7, 5))
class_acidente.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Classificação do Acidente', pad=10, fontsize=15)
plt.legend(['Com Vítimas Feridas','Com Vítimas Fatais','Sem Vítimas'],loc='upper right', bbox_to_anchor=(1.3,1) )
plt.ylabel('')
plt.show()

# %%
# agrupando os registros de acidentes por condições meteorológicas
tmp = df.groupby(by='condicao_metereologica').count()['id']

# %%
# ordenando os resgistros do maior para o menor
tempo = tmp.sort_values(ascending=False)
tempo
# Out:
# condicao_metereologica
# Céu Claro           263148
# Nublado              72956
# Chuva                54803
# Sol                  30409
# Garoa/Chuvisco       17727
# Ignorado              4632
# Nevoeiro/Neblina      4237
# Vento                 1078
# Neve                    21
# Granizo                  6
# Name: id, dtype: int64

# %%
# gráfico de acidentes por condição meteorológica
tempo.plot(kind='barh',color='red')
plt.xlabel('Quantidade de Acidentes')
plt.ylabel('Condição Meteorológica')
plt.title('Acidentes x Condição Meteorológica')
plt.show()

# %%
# filtrando registros por tipo de pista
tipo_pista = df['tipo_pista'].value_counts()
tipo_pista
# Out:
# Simples     244883
# Dupla       171818
# Múltipla     32316
# Name: tipo_pista, dtype: int64

# %%
# gráfico do percentual de acidentes por tipo de pista
plt.figure(figsize=(7, 5))
tipo_pista.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Tipo de Pista', pad=10, fontsize=15)
plt.legend(['Simples','Dupla','Múltipla',],loc='upper right', bbox_to_anchor=(1.1,1) )
plt.ylabel('')
plt.show()

# %%
tipo_ac = df['tipo_acidente'].value_counts()
tipo_ac
# Out:
# Colisão traseira                  69234
# Saída de leito carroçável         60051
# Tombamento                        57042
# Queda de ocupante de veículo      44465
# Colisão com objeto                37859
# Colisão transversal               35698
# Colisão frontal                   33534
# Colisão lateral mesmo sentido     29177
# Capotamento                       26160
# Atropelamento de Pedestre         14408
# Colisão lateral sentido oposto    12455
# Engavetamento                     11407
# Derramamento de carga              5927
# Incêndio                           4496
# Colisão lateral                    3199
# Atropelamento de Animal            2313
# Eventos atípicos                   1592
# Name: tipo_acidente, dtype: int64

# %%
# gráfico acidentes por tipo acidente
tipo_ac.plot(kind='bar',color='red')
plt.xlabel('Tipo Acidente')
plt.ylabel('Quantidade de Mortos')
plt.title('Acidentes x Tipo Acidente')
plt.show()

# %%
# agrupando óbitos por tipo de acidente
tipo = df.groupby(by='tipo_acidente').sum()['mortos']

# %%
# ordenando número de óbitos por tipo de acidente do maior para o menor
tipo_ordem = tipo.sort_values(ascending=False)
tipo_ordem
# Out:
# tipo_acidente
# Colisão frontal                   3323
# Saída de leito carroçável         3120
# Tombamento                        2541
# Queda de ocupante de veículo      2342
# Atropelamento de Pedestre         2208
# Colisão com objeto                1835
# Colisão traseira                  1378
# Capotamento                       1308
# Colisão transversal                895
# Colisão lateral mesmo sentido      584
# Colisão lateral sentido oposto     429
# Incêndio                           300
# Derramamento de carga              268
# Engavetamento                      158
# Atropelamento de Animal             83
# Eventos atípicos                    77
# Colisão lateral                     71
# Name: mortos, dtype: int64

# %%
# gráfico mortos por tipo acidente
tipo_ordem.plot(kind='bar',color='red')
plt.xlabel('Tipo Acidente')
plt.ylabel('Quantidade de Mortos')
plt.title('Mortos x Tipo Acidente')
plt.show()

# %%
# filtrando resgistro por dia da semana
dia_semana = df['dia_semana'].value_counts()
dia_semana
# Out:
# domingo          79929
# sábado           73590
# sexta-feira      71229
# segunda-feira    58259
# quarta-feira     57226
# quinta-feira     56516
# terça-feira      52268
# Name: dia_semana, dtype: int64

# %%
# gráfico registro de acidentes por dia da semana
dia_semana.plot(kind='bar',color='red')
plt.xlabel('Dia da Semana')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Dia da Semana')
plt.show()

# %%
# agrupando óbitos por dia da semana
dia = df.groupby(by='dia_semana').sum()['mortos']
dia
# Out:
# dia_semana
# domingo          4298
# quarta-feira     2157
# quinta-feira     2315
# segunda-feira    2737
# sexta-feira      3334
# sábado           3724
# terça-feira      2355
# Name: mortos, dtype: int64

# %%
# ordenando os registros do maior para o menor
dia_semana = dia.sort_values(ascending=False)
dia_semana
# Out:
# dia_semana
# domingo          4298
# sábado           3724
# sexta-feira      3334
# segunda-feira    2737
# terça-feira      2355
# quinta-feira     2315
# quarta-feira     2157
# Name: mortos, dtype: int64

# %%
# gráfico mortos por dia da semana
dia_semana.plot(kind='bar',color='red')
plt.xlabel('Dia da Semana')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Dia da Semana')
plt.show()

# %%
veiculos = df['tipo_veiculo'].value_counts()
veiculos
# Out:
# Automóvel            165554
# Motocicleta           80212
# Semireboque           39868
# Caminhonete           39566
# Caminhão-trator       37433
# Caminhão              29859
# Ônibus                16704
# Camioneta             10328
# Motoneta               8443
# Utilitário             6127
# Bicicleta              6066
# Reboque                3438
# Micro-ônibus           2818
# Outros                 1173
# Ciclomotor              846
# Trator de rodas         222
# Carroça-charrete        187
# Não Informado            76
# Carro de mão             31
# Triciclo                 25
# Quadriciclo              12
# Trator de esteira        11
# Trem-bonde                9
# Chassi-plataforma         5
# Trator misto              4
# Name: tipo_veiculo, dtype: int64

# %%
# gráfico acidentes por tipo de veículo
veiculos.plot(kind='bar',color='red')
plt.xlabel('Tipo de Veículo')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Tipo de Veículo')
plt.show()

# %%
# agrupando óbitos por tipo de veículo
tipo = df.groupby(by='tipo_veiculo').sum()['mortos']
tipo_v = tipo.sort_values(ascending=False)
tipo_v
# Out:
# tipo_veiculo
# Automóvel            6756
# Motocicleta          6459
# Caminhão-trator      1713
# Caminhonete          1392
# Caminhão             1378
# Bicicleta             763
# Ônibus                623
# Motoneta              520
# Camioneta             318
# Micro-ônibus          253
# Semireboque           244
# Utilitário            201
# Outros                163
# Ciclomotor             78
# Reboque                24
# Trator de rodas        13
# Carroça-charrete       10
# Carro de mão            8
# Triciclo                3
# Não Informado           1
# Quadriciclo             0
# Chassi-plataforma       0
# Trator de esteira       0
# Trator misto            0
# Trem-bonde              0
# Name: mortos, dtype: int64

# %%
# gráfico mortos por tipo de veículo
tipo_v.plot(kind='bar',color='red')
plt.xlabel('Tipo de Veículo')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Tipo de Veículo')
plt.show()
