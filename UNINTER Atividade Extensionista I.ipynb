# %%
# importando a biblioteca pandas 
import pandas as pd

# %%
# abrindo o dataset
df = pd.read_csv('datatran2021.csv', sep=';' , encoding='latin-1')
pd.set_option('display.max_columns', None)

# %%
# dimensões do dataset
df.shape
# Out:
# (64452, 30)

# %%
# filtrandro dados do estado de Minas Gerais
df.loc[(df['uf'] == 'MG')]
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 10     331708.0   2021-01-01   sexta-feira  01:00:00  MG  116.0   79,1
# 24     331725.0   2021-01-01   sexta-feira  04:15:00  MG  116.0  413,4
# 30     331731.0   2021-01-01   sexta-feira  05:50:00  MG   40.0    439
# 45     331791.0   2021-01-01   sexta-feira  03:50:00  MG  116.0  464,6
# 52     331800.0   2021-01-01   sexta-feira  08:30:00  MG  381.0    913
# ...         ...          ...           ...       ...  ..    ...    ...
# 64432  411604.0   2021-08-22       domingo  05:20:00  MG  262.0   48,5
# 64437  411695.0   2021-12-23  quinta-feira  08:50:00  MG  262.0    387
# 64440  411752.0   2021-12-08  quarta-feira  07:50:00  MG  381.0    492
# 64441  411754.0   2021-12-03   sexta-feira  10:30:00  MG   40.0  518,9
# 64442  411763.0   2021-10-22   sexta-feira  06:20:00  MG  381.0    543
#
#                   municipio                        causa_acidente  \
# 10                   MEDINA                     Condutor Dormindo
# 24     GOVERNADOR VALADARES               Velocidade Incompatível
# 30                PARAOPEBA               Velocidade Incompatível
# 45                TARUMIRIM  Demais falhas mecânicas ou elétricas
# 52              CAMANDUCAIA               Velocidade Incompatível
# ...                     ...                                   ...
# 64432              MANHUACU                Transitar na contramão
# 64437               JUATUBA        Ausência de reação do condutor
# 64440                 BETIM                                 Chuva
# 64441    RIBEIRAO DAS NEVES               Velocidade Incompatível
# 64442            ITATIAIUCU  Demais falhas mecânicas ou elétricas
#
#                        tipo_acidente classificacao_acidente     fase_dia  \
# 10         Saída de leito carroçável            Sem Vítimas  Plena Noite
# 24                       Capotamento     Com Vítimas Fatais    Amanhecer
# 30         Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 45         Saída de leito carroçável    Com Vítimas Feridas  Plena Noite
# 52         Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# ...                              ...                    ...          ...
# 64432                Colisão frontal    Com Vítimas Feridas    Amanhecer
# 64437               Colisão traseira    Com Vítimas Feridas    Pleno dia
# 64440  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 64441  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 64442                       Incêndio            Sem Vítimas    Amanhecer
#
#        sentido_via condicao_metereologica tipo_pista    tracado_via uso_solo  \
# 10     Decrescente              Céu Claro      Dupla  Não Informado      Não
# 24       Crescente              Céu Claro    Simples           Reta      Sim
# 30       Crescente              Céu Claro      Dupla  Não Informado      Não
# 45       Crescente                Nublado    Simples           Reta      Não
# 52       Crescente                  Chuva      Dupla  Não Informado      Não
# ...            ...                    ...        ...            ...      ...
# 64432    Crescente              Céu Claro    Simples           Reta      Não
# 64437    Crescente              Céu Claro      Dupla          Curva      Não
# 64440    Crescente                  Chuva      Dupla           Reta      Não
# 64441    Crescente                Nublado      Dupla           Reta      Sim
# 64442    Crescente                Nublado      Dupla           Reta      Não
#
#        pessoas  mortos  feridos_leves  feridos_graves  ilesos  ignorados  \
# 10           1       0              0               0       1          0
# 24           3       1              2               0       0          0
# 30           2       0              2               0       0          0
# 45           1       0              1               0       0          0
# 52           1       0              1               0       0          0
# ...        ...     ...            ...             ...     ...        ...
# 64432        2       0              1               1       0          0
# 64437        3       0              2               0       1          0
# 64440        2       0              1               0       1          0
# 64441        3       0              0               2       1          0
# 64442        1       0              0               0       1          0
#
#        feridos  veiculos   latitude  longitude regional delegacia    uop
# 10           0         1 -16.273886 -41.482124    SR-MG     UOP02  DEL11
# 24           2         1 -18.873907 -41.966366    SR-MG     UOP01  DEL06
# 30           2         1 -19.231004 -44.435622    SR-MG     UOP01  DEL02
# 45           1         1 -19.268652 -42.065696    SR-MG     UOP02  DEL06
# 52           1         1 -22.753900 -46.146503    SR-MG     UOP03  DEL16
# ...        ...       ...        ...        ...      ...       ...    ...
# 64432        2         2 -20.253734 -42.122876    SR-MG     UOP04  DEL06
# 64437        2         2 -19.934730 -44.434576    SR-MG     UOP03  DEL01
# 64440        1         2 -19.974901 -44.190043    SR-MG     UOP03  DEL01
# 64441        2         2 -19.842209 -44.075496    SR-MG     UOP02  DEL01
# 64442        0         1 -20.273368 -44.425855    SR-MG     UOP03  DEL04
#
# [8309 rows x 30 columns]

# %%
# novo_df recebe dados do estado de Minas Gerais
novo_df = df.loc[(df['uf'] == 'MG')]

# %%
# salvando os dados de Minas Gerais em arquivo csv
novo_df.to_csv('minasgerais2021.csv',index=False)

# %%
# abrindo novo arquivo com os dados de Minas Gerais
df = pd.read_csv('minasgerais2021.csv')

# %%
# dimensões do dataset (linhas,colunas)
df.shape
# Out:
# (8309, 30)

# %%
# colunas do dataset
df.columns
# Out:
# Index(['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km',
#        'municipio', 'causa_acidente', 'tipo_acidente',
#        'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos',
#        'ignorados', 'feridos', 'veiculos', 'latitude', 'longitude', 'regional',
#        'delegacia', 'uop'],
#       dtype='object')

# %%
# amostras das primeiras linhas 
df.head()
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  331708.0   2021-01-01  sexta-feira  01:00:00  MG  116.0   79,1
# 1  331725.0   2021-01-01  sexta-feira  04:15:00  MG  116.0  413,4
# 2  331731.0   2021-01-01  sexta-feira  05:50:00  MG   40.0    439
# 3  331791.0   2021-01-01  sexta-feira  03:50:00  MG  116.0  464,6
# 4  331800.0   2021-01-01  sexta-feira  08:30:00  MG  381.0    913
#
#               municipio                        causa_acidente  \
# 0                MEDINA                     Condutor Dormindo
# 1  GOVERNADOR VALADARES               Velocidade Incompatível
# 2             PARAOPEBA               Velocidade Incompatível
# 3             TARUMIRIM  Demais falhas mecânicas ou elétricas
# 4           CAMANDUCAIA               Velocidade Incompatível
#
#                tipo_acidente classificacao_acidente     fase_dia  sentido_via  \
# 0  Saída de leito carroçável            Sem Vítimas  Plena Noite  Decrescente
# 1                Capotamento     Com Vítimas Fatais    Amanhecer    Crescente
# 2  Saída de leito carroçável    Com Vítimas Feridas    Pleno dia    Crescente
# 3  Saída de leito carroçável    Com Vítimas Feridas  Plena Noite    Crescente
# 4  Saída de leito carroçável    Com Vítimas Feridas    Pleno dia    Crescente
#
#   condicao_metereologica tipo_pista    tracado_via uso_solo  pessoas  mortos  \
# 0              Céu Claro      Dupla  Não Informado      Não        1       0
# 1              Céu Claro    Simples           Reta      Sim        3       1
# 2              Céu Claro      Dupla  Não Informado      Não        2       0
# 3                Nublado    Simples           Reta      Não        1       0
# 4                  Chuva      Dupla  Não Informado      Não        1       0
#
#    feridos_leves  feridos_graves  ilesos  ignorados  feridos  veiculos  \
# 0              0               0       1          0        0         1
# 1              2               0       0          0        2         1
# 2              2               0       0          0        2         1
# 3              1               0       0          0        1         1
# 4              1               0       0          0        1         1
#
#     latitude  longitude regional delegacia    uop
# 0 -16.273886 -41.482124    SR-MG     UOP02  DEL11
# 1 -18.873907 -41.966366    SR-MG     UOP01  DEL06
# 2 -19.231004 -44.435622    SR-MG     UOP01  DEL02
# 3 -19.268652 -42.065696    SR-MG     UOP02  DEL06
# 4 -22.753900 -46.146503    SR-MG     UOP03  DEL16

# %%
# valores ausentes
df.isnull().sum()
# Out:
# id                         0
# data_inversa               0
# dia_semana                 0
# horario                    0
# uf                         0
# br                        12
# km                        12
# municipio                  0
# causa_acidente             0
# tipo_acidente              0
# classificacao_acidente     0
# fase_dia                   0
# sentido_via                0
# condicao_metereologica     0
# tipo_pista                 0
# tracado_via                0
# uso_solo                   0
# pessoas                    0
# mortos                     0
# feridos_leves              0
# feridos_graves             0
# ilesos                     0
# ignorados                  0
# feridos                    0
# veiculos                   0
# latitude                   0
# longitude                  0
# regional                   0
# delegacia                  0
# uop                        0
# dtype: int64

# %%
acidentes = df['id'].count()
print(f"Total de acidentes em 2021:",acidentes)
# Out:
# Total de acidentes em 2021: 8309

# %%
df['delegacia'].unique()
# Out:
# array(['UOP02', 'UOP01', 'UOP03', 'UOP04', 'DEL01'], dtype=object)

# %%
df['regional'].unique()
# Out:
# array(['SR-MG', 'SR-BA'], dtype=object)

# %%
df['uop'].unique
# Out:
# <bound method Series.unique of 0       DEL11
# 1       DEL06
# 2       DEL02
# 3       DEL06
# 4       DEL16
#         ...
# 8304    DEL06
# 8305    DEL01
# 8306    DEL01
# 8307    DEL01
# 8308    DEL04
# Name: uop, Length: 8309, dtype: object>

# %%
# amostras das últimas 10 linhas
df.tail(10)
# Out:
#             id data_inversa     dia_semana   horario  uf     br     km  \
# 8299  411079.0   2021-09-14    terça-feira  18:00:00  MG  381.0    356
# 8300  411145.0   2021-08-15        domingo  18:20:00  MG  381.0  159,5
# 8301  411178.0   2021-10-18  segunda-feira  15:40:00  MG   40.0  730,3
# 8302  411221.0   2021-07-23    sexta-feira  19:50:00  MG  381.0    484
# 8303  411332.0   2021-11-28        domingo  14:40:00  MG   40.0  786,9
# 8304  411604.0   2021-08-22        domingo  05:20:00  MG  262.0   48,5
# 8305  411695.0   2021-12-23   quinta-feira  08:50:00  MG  262.0    387
# 8306  411752.0   2021-12-08   quarta-feira  07:50:00  MG  381.0    492
# 8307  411754.0   2021-12-03    sexta-feira  10:30:00  MG   40.0  518,9
# 8308  411763.0   2021-10-22    sexta-feira  06:20:00  MG  381.0    543
#
#                  municipio                            causa_acidente  \
# 8299        JOAO MONLEVADE          Ingestão de álcool pelo condutor
# 8300  GOVERNADOR VALADARES                   Velocidade Incompatível
# 8301       OLIVEIRA FORTES                                     Chuva
# 8302                 BETIM  Reação tardia ou ineficiente do condutor
# 8303          JUIZ DE FORA            Ausência de reação do condutor
# 8304              MANHUACU                    Transitar na contramão
# 8305               JUATUBA            Ausência de reação do condutor
# 8306                 BETIM                                     Chuva
# 8307    RIBEIRAO DAS NEVES                   Velocidade Incompatível
# 8308            ITATIAIUCU      Demais falhas mecânicas ou elétricas
#
#                       tipo_acidente classificacao_acidente     fase_dia  \
# 8299            Colisão transversal    Com Vítimas Feridas    Anoitecer
# 8300                     Tombamento    Com Vítimas Feridas  Plena Noite
# 8301             Colisão com objeto    Com Vítimas Feridas    Pleno dia
# 8302                     Tombamento    Com Vítimas Feridas    Anoitecer
# 8303               Colisão traseira    Com Vítimas Feridas    Pleno dia
# 8304                Colisão frontal    Com Vítimas Feridas    Amanhecer
# 8305               Colisão traseira    Com Vítimas Feridas    Pleno dia
# 8306  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 8307  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 8308                       Incêndio            Sem Vítimas    Amanhecer
#
#       sentido_via condicao_metereologica tipo_pista    tracado_via uso_solo  \
# 8299  Decrescente              Céu Claro    Simples  Não Informado      Sim
# 8300  Decrescente              Céu Claro    Simples  Não Informado      Não
# 8301  Decrescente                  Chuva      Dupla  Não Informado      Não
# 8302    Crescente              Céu Claro   Múltipla          Curva      Sim
# 8303  Decrescente              Céu Claro      Dupla          Curva      Não
# 8304    Crescente              Céu Claro    Simples           Reta      Não
# 8305    Crescente              Céu Claro      Dupla          Curva      Não
# 8306    Crescente                  Chuva      Dupla           Reta      Não
# 8307    Crescente                Nublado      Dupla           Reta      Sim
# 8308    Crescente                Nublado      Dupla           Reta      Não
#
#       pessoas  mortos  feridos_leves  feridos_graves  ilesos  ignorados  \
# 8299        3       0              1               1       0          1
# 8300        1       0              1               0       0          0
# 8301        1       0              1               0       0          0
# 8302        4       0              2               0       0          2
# 8303        3       0              1               0       2          0
# 8304        2       0              1               1       0          0
# 8305        3       0              2               0       1          0
# 8306        2       0              1               0       1          0
# 8307        3       0              0               2       1          0
# 8308        1       0              0               0       1          0
#
#       feridos  veiculos   latitude  longitude regional delegacia    uop
# 8299        2         2 -19.847654 -43.205664    SR-MG     UOP01  DEL03
# 8300        1         1 -18.891223 -42.004595    SR-MG     UOP01  DEL06
# 8301        1         1 -21.333790 -43.586621    SR-MG     UOP01  DEL05
# 8302        2         3 -19.955317 -44.117222    SR-MG     UOP03  DEL01
# 8303        1         2 -21.751490 -43.445289    SR-MG     UOP01  DEL05
# 8304        2         2 -20.253734 -42.122876    SR-MG     UOP04  DEL06
# 8305        2         2 -19.934730 -44.434576    SR-MG     UOP03  DEL01
# 8306        1         2 -19.974901 -44.190043    SR-MG     UOP03  DEL01
# 8307        2         2 -19.842209 -44.075496    SR-MG     UOP02  DEL01
# 8308        0         1 -20.273368 -44.425855    SR-MG     UOP03  DEL04

# %%
# valores estatísticos básicos
df.describe()
#count -> total registros
#mean -> média
#std -> desvio padrão
#min -> valor mínimo encontrado
#25% 
#50% -> pode se dizer a mediana
#75%
#max -> valor máximo encontrado
# Out:
#                   id           br      pessoas       mortos  feridos_leves  \
# count    8309.000000  8297.000000  8309.000000  8309.000000    8309.000000
# mean   369642.385726   222.386646     2.288843     0.083404       0.910820
# std     21470.191346   144.624344     1.850737     0.333350       1.122435
# min    331708.000000    40.000000     1.000000     0.000000       0.000000
# 25%    351421.000000    50.000000     1.000000     0.000000       0.000000
# 50%    369836.000000   262.000000     2.000000     0.000000       1.000000
# 75%    388319.000000   381.000000     3.000000     0.000000       1.000000
# max    411763.000000   459.000000    53.000000     5.000000      44.000000
#
#        feridos_graves       ilesos    ignorados      feridos     veiculos  \
# count     8309.000000  8309.000000  8309.000000  8309.000000  8309.000000
# mean         0.287881     0.858106     0.148634     1.198700     1.564448
# std          0.591973     1.309097     0.437945     1.213437     0.748352
# min          0.000000     0.000000     0.000000     0.000000     1.000000
# 25%          0.000000     0.000000     0.000000     1.000000     1.000000
# 50%          0.000000     1.000000     0.000000     1.000000     1.000000
# 75%          0.000000     1.000000     0.000000     1.000000     2.000000
# max         13.000000    46.000000     6.000000    49.000000    12.000000
#
#           latitude    longitude
# count  8309.000000  8309.000000
# mean    -19.861811   -44.713680
# std       1.424205     2.081650
# min     -22.876994   -50.438424
# 25%     -20.610954   -46.038589
# 50%     -19.880044   -44.203180
# 75%     -18.986906   -43.426209
# max     -15.719375   -41.330362

# %%
# ordenando as datas
df.sort_values('data_inversa')
# Out:
#             id data_inversa   dia_semana   horario  uf     br     km  \
# 0     331708.0   2021-01-01  sexta-feira  01:00:00  MG  116.0   79,1
# 1854  349034.0   2021-01-01  sexta-feira  14:20:00  MG  381.0    502
# 6578  390992.0   2021-01-01  sexta-feira  17:35:00  MG   40.0   79,3
# 15    331937.0   2021-01-01  sexta-feira  22:05:00  MG  116.0  604,3
# 13    331924.0   2021-01-01  sexta-feira  20:30:00  MG  381.0    510
# ...        ...          ...          ...       ...  ..    ...    ...
# 8232  405069.0   2021-12-31  sexta-feira  16:15:00  MG  381.0    344
# 8231  405051.0   2021-12-31  sexta-feira  14:40:00  MG   40.0  764,5
# 8230  405049.0   2021-12-31  sexta-feira  13:45:00  MG  365.0   51,2
# 8236  405089.0   2021-12-31  sexta-feira  09:00:00  MG  116.0  237,8
# 8227  405045.0   2021-12-31  sexta-feira  14:20:00  MG   40.0  777,3
#
#                  municipio                                     causa_acidente  \
# 0                   MEDINA                                  Condutor Dormindo
# 1854                 BETIM                     Ausência de reação do condutor
# 6578              PARACATU                     Ausência de reação do condutor
# 15    SAO JOAO DO MANHUACU  Ingestão de álcool ou de substâncias psicoativ...
# 13    SAO JOAQUIM DE BICAS             Pedestre cruzava a pista fora da faixa
# ...                    ...                                                ...
# 8232   BELA VISTA DE MINAS                            Velocidade Incompatível
# 8231          JUIZ DE FORA                            Velocidade Incompatível
# 8230      CLARO DOS POCOES                  Acumulo de óleo sobre o pavimento
# 8236         TEOFILO OTONI                               Demais falhas na via
# 8227          JUIZ DE FORA                                              Chuva
#
#                        tipo_acidente classificacao_acidente     fase_dia  \
# 0          Saída de leito carroçável            Sem Vítimas  Plena Noite
# 1854              Colisão com objeto            Sem Vítimas    Pleno dia
# 6578       Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 15    Colisão lateral sentido oposto            Sem Vítimas  Plena Noite
# 13         Atropelamento de Pedestre    Com Vítimas Feridas  Plena Noite
# ...                              ...                    ...          ...
# 8232                 Colisão frontal    Com Vítimas Feridas    Pleno dia
# 8231                 Colisão frontal    Com Vítimas Feridas    Pleno dia
# 8230       Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 8236              Colisão com objeto    Com Vítimas Feridas    Pleno dia
# 8227              Colisão com objeto    Com Vítimas Feridas    Pleno dia
#
#       sentido_via condicao_metereologica tipo_pista    tracado_via uso_solo  \
# 0     Decrescente              Céu Claro      Dupla  Não Informado      Não
# 1854    Crescente              Céu Claro      Dupla          Curva      Não
# 6578  Decrescente                  Chuva    Simples           Reta      Não
# 15    Decrescente                  Chuva    Simples          Curva      Não
# 13    Decrescente                  Chuva   Múltipla           Reta      Sim
# ...           ...                    ...        ...            ...      ...
# 8232    Crescente                  Chuva    Simples          Curva      Não
# 8231  Decrescente                  Chuva    Simples          Curva      Não
# 8230    Crescente                  Chuva    Simples          Curva      Não
# 8236    Crescente                Nublado    Simples           Reta      Não
# 8227    Crescente                  Chuva      Dupla           Reta      Não
#
#       pessoas  mortos  feridos_leves  feridos_graves  ilesos  ignorados  \
# 0           1       0              0               0       1          0
# 1854        1       0              0               0       1          0
# 6578        3       0              3               0       0          0
# 15          2       0              0               0       0          2
# 13          2       0              0               1       0          1
# ...       ...     ...            ...             ...     ...        ...
# 8232        3       0              1               1       1          0
# 8231        7       0              3               3       1          0
# 8230        1       0              1               0       0          0
# 8236        1       0              1               0       0          0
# 8227        4       0              2               0       2          0
#
#       feridos  veiculos   latitude  longitude regional delegacia    uop
# 0           0         1 -16.273886 -41.482124    SR-MG     UOP02  DEL11
# 1854        0         1 -20.036197 -44.245863    SR-MG     UOP03  DEL01
# 6578        3         1 -17.457030 -46.668745    SR-MG     UOP01  DEL14
# 15          0         2 -20.361450 -42.150350    SR-MG     UOP04  DEL06
# 13          1         1 -20.077382 -44.304345    SR-MG     UOP03  DEL01
# ...       ...       ...        ...        ...      ...       ...    ...
# 8232        2         2 -19.859868 -43.112810    SR-MG     UOP01  DEL03
# 8231        6         2 -21.560659 -43.498652    SR-MG     UOP01  DEL05
# 8230        1         1 -16.949504 -44.243745    SR-MG     UOP01  DEL12
# 8236        1         1 -17.546513 -41.476685    SR-MG     UOP01  DEL11
# 8227        2         1 -21.659154 -43.433517    SR-MG     UOP01  DEL05
#
# [8309 rows x 30 columns]

# %%
# soma do total de feridos no estado
feridos = df['feridos'].sum()
print(f"Total de feridos no estado:",feridos)
# Out:
# Total de feridos no estado: 9960

# %%
# soma do total de mortos no estado
mortos = df['mortos'].sum()
print(f"Total de mortos no estado:",mortos)
# Out:
# Total de mortos no estado: 693

# %%
# maior número de feridos em um acidente
df['feridos'].max()
# Out:
# 49

# %%
# localizando o registro do acidente onde houve o maior número de feridos 
df.loc[df['feridos'] == 49]
# Out:
#             id data_inversa dia_semana   horario  uf     br     km  \
# 6088  387236.0   2021-10-02     sábado  22:50:00  MG  116.0  774,3
#
#        municipio causa_acidente              tipo_acidente  \
# 6088  LEOPOLDINA          Chuva  Saída de leito carroçável
#
#      classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# 6088     Com Vítimas Fatais  Plena Noite  Decrescente                  Chuva
#
#      tipo_pista    tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 6088    Simples  Não Informado      Não       53       4             44
#
#       feridos_graves  ilesos  ignorados  feridos  veiculos   latitude  \
# 6088               5       0          0       49         1 -21.579321
#
#       longitude regional delegacia    uop
# 6088  -42.68265    SR-MG     UOP01  DEL07

# %%
# maior número de óbitos em um acidente
df['mortos'].max()
# Out:
# 5

# %%
# localizando os registros de acidentes onde houve o maior número de óbitos 
df.loc[df['mortos'] == 5]
# Out:
#             id data_inversa   dia_semana   horario  uf     br     km  \
# 266   334035.0   2021-01-12  terça-feira  15:45:00  MG  251.0    506
# 7752  401397.0   2021-12-12      domingo  23:30:00  MG   40.0  565,7
# 8095  404152.0   2021-12-26      domingo  16:05:00  MG   40.0  760,2
# 8262  407093.0   2021-10-31      domingo  14:40:00  MG  365.0    727
#
#                   municipio           causa_acidente    tipo_acidente  \
# 266            FRANCISCO SA  Velocidade Incompatível  Colisão frontal
# 7752              NOVA LIMA                    Chuva  Colisão frontal
# 8095           JUIZ DE FORA        Condutor Dormindo  Colisão frontal
# 8262  MONTE ALEGRE DE MINAS  Velocidade Incompatível  Colisão frontal
#
#      classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# 266      Com Vítimas Fatais    Pleno dia  Decrescente              Céu Claro
# 7752     Com Vítimas Fatais  Plena Noite  Decrescente                  Chuva
# 8095     Com Vítimas Fatais    Pleno dia  Decrescente                  Chuva
# 8262     Com Vítimas Fatais    Pleno dia    Crescente                  Chuva
#
#      tipo_pista    tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 266     Simples           Reta      Não        6       5              0
# 7752    Simples  Não Informado      Sim        6       5              0
# 8095    Simples  Não Informado      Não       26       5              1
# 8262    Simples  Não Informado      Não        6       5              0
#
#       feridos_graves  ilesos  ignorados  feridos  veiculos   latitude  \
# 266                1       0          0        1         2 -16.618949
# 7752               0       1          0        0         2 -20.169851
# 8095               1      19          0        2         2 -21.561092
# 8262               0       1          0        0         2 -18.896610
#
#       longitude regional delegacia    uop
# 266  -43.688783    SR-MG     UOP01  DEL12
# 7752 -43.965548    SR-MG     UOP02  DEL01
# 8095 -43.495774    SR-MG     UOP01  DEL05
# 8262 -49.251117    SR-MG     UOP03  DEL15

# %%
# soma de pessoas envolvidas nos acidentes
df['pessoas'].sum()
# Out:
# 19018

# %%
# soma de ilesos
df['ilesos'].sum()
# Out:
# 7130

# %%
# número máximo de pessoas envolvidas no acidente
df['pessoas'].max()
# Out:
# 53

# %%
# localizando o registro do acidente onde teve o maior número de pessoas envolvidas
df.loc[df['pessoas'] == 53]
# Out:
#             id data_inversa dia_semana   horario  uf     br     km  \
# 6088  387236.0   2021-10-02     sábado  22:50:00  MG  116.0  774,3
#
#        municipio causa_acidente              tipo_acidente  \
# 6088  LEOPOLDINA          Chuva  Saída de leito carroçável
#
#      classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# 6088     Com Vítimas Fatais  Plena Noite  Decrescente                  Chuva
#
#      tipo_pista    tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 6088    Simples  Não Informado      Não       53       4             44
#
#       feridos_graves  ilesos  ignorados  feridos  veiculos   latitude  \
# 6088               5       0          0       49         1 -21.579321
#
#       longitude regional delegacia    uop
# 6088  -42.68265    SR-MG     UOP01  DEL07

# %%
# valores da coluna causa_acidente
df['causa_acidente'].unique()
# Out:
# array(['Condutor Dormindo', 'Velocidade Incompatível',
#        'Demais falhas mecânicas ou elétricas',
#        'Acessar a via sem observar a presença dos outros veículos',
#        'Avarias e/ou desgaste excessivo no pneu',
#        'Pedestre cruzava a pista fora da faixa', 'Transitar na contramão',
#        'Ingestão de álcool ou de substâncias psicoativas pelo pedestre',
#        'Animais na Pista',
#        'Condutor deixou de manter distância do veículo da frente',
#        'Pista Escorregadia', 'Chuva', 'Conversão proibida',
#        'Reação tardia ou ineficiente do condutor',
#        'Acumulo de água sobre o pavimento',
#        'Ausência de reação do condutor',
#        'Ingestão de álcool pelo condutor',
#        'Afundamento ou ondulação no pavimento',
#        'Acumulo de areia ou detritos sobre o pavimento',
#        'Manobra de mudança de faixa',
#        'Objeto estático sobre o leito carroçável', 'Retorno proibido',
#        'Ultrapassagem Indevida',
#        'Desrespeitar a preferência no cruzamento',
#        'Carga excessiva e/ou mal acondicionada',
#        'Pedestre andava na pista', 'Acesso irregular',
#        'Deixar de acionar o farol da motocicleta (ou similar)',
#        'Transitar no acostamento', 'Mal súbito do condutor',
#        'Estacionar ou parar em local proibido', 'Condutor usando celular',
#        'Acumulo de óleo sobre o pavimento', 'Curva acentuada',
#        'Ingestão de álcool e/ou substâncias psicoativas pelo pedestre',
#        'Ausência de sinalização', 'Pista em desnível',
#        'Demais falhas na via', 'Pista esburacada',
#        'Falta de elemento de contenção que evite a saída do leito carroçável',
#        'Ingestão de substâncias psicoativas pelo condutor',
#        'Trafegar com motocicleta (ou similar) entre as faixas',
#        'Desvio temporário', 'Demais Fenômenos da natureza',
#        'Obras na pista', 'Problema com o freio',
#        'Restrição de visibilidade em curvas verticais',
#        'Frear bruscamente', 'Entrada inopinada do pedestre',
#        'Acostamento em desnível', 'Obstrução na via',
#        'Área urbana sem a presença de local apropriado para a travessia de pedestres',
#        'Sinalização mal posicionada', 'Falta de acostamento',
#        'Iluminação deficiente',
#        'Deficiência do Sistema de Iluminação/Sinalização',
#        'Problema na suspensão', 'Declive acentuado', 'Neblina', 'Fumaça',
#        'Faixas de trânsito com largura insuficiente',
#        'Restrição de visibilidade em curvas horizontais',
#        'Sistema de drenagem ineficiente'], dtype=object)

# %%
# agrupamento acidentes por causa
acidente = df.groupby(['causa_acidente']).size().sort_values(ascending=False)
acidente_mais_20 = acidente[acidente>=20]
acidente_mais_20
# Out:
# causa_acidente
# Velocidade Incompatível                                          1651
# Ausência de reação do condutor                                    842
# Reação tardia ou ineficiente do condutor                          781
# Acessar a via sem observar a presença dos outros veículos         458
# Condutor Dormindo                                                 447
# Condutor deixou de manter distância do veículo da frente          446
# Demais falhas mecânicas ou elétricas                              428
# Ingestão de álcool pelo condutor                                  363
# Manobra de mudança de faixa                                       328
# Chuva                                                             254
# Transitar na contramão                                            206
# Avarias e/ou desgaste excessivo no pneu                           171
# Ultrapassagem Indevida                                            162
# Desrespeitar a preferência no cruzamento                          153
# Animais na Pista                                                  129
# Conversão proibida                                                117
# Pedestre andava na pista                                           99
# Pista Escorregadia                                                 92
# Pedestre cruzava a pista fora da faixa                             74
# Mal súbito do condutor                                             72
# Objeto estático sobre o leito carroçável                           66
# Entrada inopinada do pedestre                                      63
# Pista esburacada                                                   61
# Carga excessiva e/ou mal acondicionada                             58
# Transitar no acostamento                                           56
# Acumulo de água sobre o pavimento                                  56
# Trafegar com motocicleta (ou similar) entre as faixas              54
# Acesso irregular                                                   42
# Problema com o freio                                               42
# Frear bruscamente                                                  42
# Retorno proibido                                                   41
# Curva acentuada                                                    40
# Ingestão de álcool e/ou substâncias psicoativas pelo pedestre      40
# Demais falhas na via                                               40
# Acumulo de areia ou detritos sobre o pavimento                     39
# Acumulo de óleo sobre o pavimento                                  33
# Condutor usando celular                                            23
# Ausência de sinalização                                            21
# Estacionar ou parar em local proibido                              21
# Obras na pista                                                     20
# dtype: int64

# %%
# gráfico principais causas de acidente
import matplotlib.pyplot as plt
acidente_mais_20.plot(kind='bar')
plt.xlabel('Causa do Acidente')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Cauda do Acidente')
plt.show()

# %%
# agrupamento de causa acidente x mortos
causa_acidente = df.groupby(by='causa_acidente').sum()['mortos']

# %%
# filtrando registro onde teve óbitos
causa_maior_0 = causa_acidente[causa_acidente>0]

# %%
# ordenando os registros do maior para o menor
causa_maior_0.sort_values(ascending=False)
# Out:
# causa_acidente
# Velocidade Incompatível                                                         142
# Ausência de reação do condutor                                                   77
# Transitar na contramão                                                           61
# Condutor Dormindo                                                                57
# Reação tardia ou ineficiente do condutor                                         42
# Pedestre andava na pista                                                         40
# Acessar a via sem observar a presença dos outros veículos                        37
# Ultrapassagem Indevida                                                           27
# Chuva                                                                            27
# Entrada inopinada do pedestre                                                    25
# Manobra de mudança de faixa                                                      22
# Pedestre cruzava a pista fora da faixa                                           15
# Ingestão de álcool pelo condutor                                                 14
# Condutor deixou de manter distância do veículo da frente                         11
# Trafegar com motocicleta (ou similar) entre as faixas                             9
# Avarias e/ou desgaste excessivo no pneu                                           9
# Transitar no acostamento                                                          9
# Conversão proibida                                                                7
# Mal súbito do condutor                                                            6
# Problema com o freio                                                              5
# Demais falhas mecânicas ou elétricas                                              5
# Acumulo de água sobre o pavimento                                                 5
# Pista Escorregadia                                                                4
# Área urbana sem a presença de local apropriado para a travessia de pedestres      4
# Curva acentuada                                                                   4
# Animais na Pista                                                                  3
# Desrespeitar a preferência no cruzamento                                          3
# Deficiência do Sistema de Iluminação/Sinalização                                  3
# Acumulo de areia ou detritos sobre o pavimento                                    2
# Objeto estático sobre o leito carroçável                                          2
# Ausência de sinalização                                                           2
# Condutor usando celular                                                           2
# Ingestão de álcool e/ou substâncias psicoativas pelo pedestre                     2
# Ingestão de álcool ou de substâncias psicoativas pelo pedestre                    1
# Sinalização mal posicionada                                                       1
# Acumulo de óleo sobre o pavimento                                                 1
# Pista esburacada                                                                  1
# Pista em desnível                                                                 1
# Demais falhas na via                                                              1
# Falta de acostamento                                                              1
# Acesso irregular                                                                  1
# Fumaça                                                                            1
# Falta de elemento de contenção que evite a saída do leito carroçável              1
# Name: mortos, dtype: int64

# %%
# primeiras 20 linhas
causa_acidente20 = causa_maior_0.sort_values(ascending=False).head(20)
causa_acidente20
# Out:
# causa_acidente
# Velocidade Incompatível                                      142
# Ausência de reação do condutor                                77
# Transitar na contramão                                        61
# Condutor Dormindo                                             57
# Reação tardia ou ineficiente do condutor                      42
# Pedestre andava na pista                                      40
# Acessar a via sem observar a presença dos outros veículos     37
# Ultrapassagem Indevida                                        27
# Chuva                                                         27
# Entrada inopinada do pedestre                                 25
# Manobra de mudança de faixa                                   22
# Pedestre cruzava a pista fora da faixa                        15
# Ingestão de álcool pelo condutor                              14
# Condutor deixou de manter distância do veículo da frente      11
# Trafegar com motocicleta (ou similar) entre as faixas          9
# Avarias e/ou desgaste excessivo no pneu                        9
# Transitar no acostamento                                       9
# Conversão proibida                                             7
# Mal súbito do condutor                                         6
# Problema com o freio                                           5
# Name: mortos, dtype: int64

# %%
# gráfico mortos x causa do acidente
causa_acidente20.plot(kind='bar')
plt.xlabel('Causa do Acidente')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Causa do Acidente')
plt.show()

# %%
# agrupamento dos registros por br
registros_rodv = df.groupby(['br']).size()
reg_rodovia = registros_rodv.sort_values(ascending=False)
reg_rodovia
# Out:
# br
# 381.0    2386
# 40.0     1753
# 116.0    1089
# 262.0     906
# 50.0      619
# 365.0     589
# 251.0     230
# 153.0     212
# 267.0     148
# 459.0      99
# 354.0      90
# 356.0      69
# 146.0      65
# 364.0      42
# dtype: int64

# %%
# gráfico acidentes x rodovia
reg_rodovia.plot(kind='bar')
plt.xlabel('BR')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Rodovia')
plt.show()

# %%
# filtrando e agrupando os dados referente as rodovias 
qual_rodovia = df.groupby(by='br').sum()
qual_rodovia
# Out:
#                 id  pessoas  mortos  feridos_leves  feridos_graves  ilesos  \
# br
# 40.0   646836020.0     4210     145           1610             565    1641
# 50.0   228522488.0     1258      26            534             125     478
# 116.0  402245288.0     2521     108           1012             374     828
# 146.0   23968999.0      144       2             64              14      58
# 153.0   78509858.0      464      21            176              65     170
# 251.0   84622582.0      509      30            184              73     194
# 262.0  335241044.0     1969      78            764             249     756
# 267.0   55068643.0      335      22            134              59     103
# 354.0   33158213.0      186       3             72              19      81
# 356.0   25823879.0      174       3             72              25      55
# 364.0   15598757.0       95       5             36              19      27
# 365.0  217530650.0     1398      79            520             182     515
# 381.0  883100413.0     5479     162           2283             591    2128
# 459.0   36666518.0      248       9            102              30      81
#
#        ignorados  feridos  veiculos      latitude      longitude
# br
# 40.0         249     2175      2777 -34989.169436  -77572.234433
# 50.0          95      659       905 -11853.938703  -29777.912639
# 116.0        199     1386      1757 -20864.908924  -45716.232427
# 146.0          6       78        99  -1404.591605   -3021.211530
# 153.0         32      241       332  -4075.297109  -10398.852918
# 251.0         28      257       334  -3761.014842   -9887.617467
# 262.0        122     1013      1379 -18041.359517  -40633.898595
# 267.0         17      193       216  -3224.970892   -6458.276932
# 354.0         11       91       149  -1993.209735   -4043.400043
# 356.0         19       97       121  -1457.822859   -2921.266929
# 364.0          8       55        61   -841.932083   -2052.716200
# 365.0        102      702       906 -10877.182820  -27901.518318
# 381.0        315     2874      3778 -49234.517250 -106051.998626
# 459.0         26      132       165  -2189.206216   -4563.724566

# %%
# soma de óbitos por rodovia
m_rodovia = qual_rodovia.groupby(by='br').sum()['mortos']
m_rodovia
# Out:
# br
# 40.0     145
# 50.0      26
# 116.0    108
# 146.0      2
# 153.0     21
# 251.0     30
# 262.0     78
# 267.0     22
# 354.0      3
# 356.0      3
# 364.0      5
# 365.0     79
# 381.0    162
# 459.0      9
# Name: mortos, dtype: int64

# %%
# ordenando os valores do maior para o menor
rodovia = m_rodovia.sort_values(ascending=False)
rodovia
# Out:
# br
# 381.0    162
# 40.0     145
# 116.0    108
# 365.0     79
# 262.0     78
# 251.0     30
# 50.0      26
# 267.0     22
# 153.0     21
# 459.0      9
# 364.0      5
# 354.0      3
# 356.0      3
# 146.0      2
# Name: mortos, dtype: int64

# %%
# gráfico óbitos por rodovia
rodovia.plot(kind='bar')
plt.xlabel('BR')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Rodovia')
plt.show()

# %%
# agrupamento de registros de acidentes por dia da semana
r_dia = df.groupby(by='dia_semana').count()['id']
r_dia
# Out:
# dia_semana
# domingo          1402
# quarta-feira     1017
# quinta-feira     1084
# segunda-feira    1083
# sexta-feira      1297
# sábado           1446
# terça-feira       980
# Name: id, dtype: int64

# %%
# ordenando os registros do maior para o menor
dia_semana_acidente = r_dia.sort_values(ascending=False)
dia_semana_acidente
# Out:
# dia_semana
# sábado           1446
# domingo          1402
# sexta-feira      1297
# quinta-feira     1084
# segunda-feira    1083
# quarta-feira     1017
# terça-feira       980
# Name: id, dtype: int64

# %%
# gráfico registro de acidentes por dia da semana
dia_semana_acidente.plot(kind='bar')
plt.xlabel('Dia da Semana')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Dia da Semana')
plt.show()

# %%
# agrupamento de óbitos por dia da semana
dia = df.groupby(by='dia_semana').sum()['mortos']
dia
# Out:
# dia_semana
# domingo          149
# quarta-feira      84
# quinta-feira      67
# segunda-feira     85
# sexta-feira       97
# sábado           125
# terça-feira       86
# Name: mortos, dtype: int64

# %%
# ordenando os registros do maior para o menor
dia_semana = dia.sort_values(ascending=False)
dia_semana
# Out:
# dia_semana
# domingo          149
# sábado           125
# sexta-feira       97
# terça-feira       86
# segunda-feira     85
# quarta-feira      84
# quinta-feira      67
# Name: mortos, dtype: int64

# %%
# gráfico mortos por dia da semana
dia_semana.plot(kind='bar')
plt.xlabel('Dia da Semana')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Dia da Semana')
plt.show()

# %%
# valores da coluna tipo_acidente
df['tipo_acidente'].unique()
# Out:
# array(['Saída de leito carroçável', 'Capotamento', 'Colisão transversal',
#        'Colisão traseira', 'Atropelamento de Pedestre',
#        'Colisão lateral sentido oposto', 'Colisão com objeto',
#        'Colisão lateral mesmo sentido', 'Tombamento', 'Colisão lateral',
#        'Incêndio', 'Colisão frontal', 'Queda de ocupante de veículo',
#        'Derramamento de carga', 'Engavetamento',
#        'Atropelamento de Animal', 'Eventos atípicos'], dtype=object)

# %%
# agrupamento de óbitos por tipo acidente
tipo = df.groupby(by='tipo_acidente').sum()['mortos']

# %%
# ordenando número de óbitos por tipo acidente do maior para o menor, onde houve óbitos
tipo_ac = tipo.sort_values(ascending=False)
tipo_acidente = tipo_ac[tipo>0]
tipo_acidente
# Out:
# tipo_acidente
# Colisão frontal                   203
# Saída de leito carroçável         116
# Atropelamento de Pedestre          96
# Tombamento                         61
# Colisão traseira                   55
# Colisão transversal                46
# Colisão com objeto                 37
# Colisão lateral sentido oposto     22
# Colisão lateral mesmo sentido      21
# Capotamento                        16
# Engavetamento                       8
# Queda de ocupante de veículo        6
# Colisão lateral                     2
# Atropelamento de Animal             2
# Derramamento de carga               1
# Eventos atípicos                    1
# Name: mortos, dtype: int64

# %%
# gráfico mortos por tipo acidente
tipo_acidente.plot(kind='bar')
plt.xlabel('Tipo Acidente')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Tipo Acidente')
plt.show()

# %%
# agrupamento de óbitos por município onde houve 10 ou mais registros
municipio = df.groupby(by='municipio').sum()['mortos']
muni_mortos = municipio[municipio>=10]
muni_mortos
# Out:
# municipio
# BETIM                    12
# CONSELHEIRO LAFAIETE     11
# CONTAGEM                 13
# FRANCISCO SA             16
# JOAO MONLEVADE           14
# JUIZ DE FORA             15
# LEOPOLDINA               12
# MANHUACU                 13
# MONTE ALEGRE DE MINAS    14
# MONTES CLAROS            17
# NOVA LIMA                15
# NOVA SERRANA             12
# SABARA                   15
# TEOFILO OTONI            12
# UBERABA                  14
# UBERLANDIA               29
# Name: mortos, dtype: int64

# %%
# ordenando os registros do maior para o menor
municipio_mortos_ord = muni_mortos.sort_values(ascending=False)
municipio_mortos_ord
# Out:
# municipio
# UBERLANDIA               29
# MONTES CLAROS            17
# FRANCISCO SA             16
# JUIZ DE FORA             15
# NOVA LIMA                15
# SABARA                   15
# JOAO MONLEVADE           14
# MONTE ALEGRE DE MINAS    14
# UBERABA                  14
# CONTAGEM                 13
# MANHUACU                 13
# BETIM                    12
# LEOPOLDINA               12
# NOVA SERRANA             12
# TEOFILO OTONI            12
# CONSELHEIRO LAFAIETE     11
# Name: mortos, dtype: int64

# %%
# gráfico mortos por municipio onde houve 10 ou mais registros
municipio_mortos_ord.plot(kind='bar')
plt.xlabel('Município')
plt.ylabel('Quantidade de Óbitos')
plt.title('Mortos x Município (mais de 10 registros)')
plt.show()

# %%
# valores da coluna tipo_pista
df['tipo_pista'].unique()
# Out:
# array(['Dupla', 'Simples', 'Múltipla'], dtype=object)

# %%
# agrupamento dos registros de acidentes por tipo de pista
tipo_pista = df.groupby(by='tipo_pista').count()['id']
tipo_pista
# Out:
# tipo_pista
# Dupla       3849
# Múltipla     342
# Simples     4118
# Name: id, dtype: int64

# %%
# ordenando os registros do maior para o menor
t_pista = tipo_pista.sort_values(ascending=False)
t_pista
# Out:
# tipo_pista
# Simples     4118
# Dupla       3849
# Múltipla     342
# Name: id, dtype: int64

# %%
# gráfico do percentual de acidentes por tipo de pista
plt.figure(figsize=(7, 5))
t_pista.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Tipo de Pista', pad=10, fontsize=15)
plt.legend(['Simples','Dupla','Múltipla',],loc='upper right', bbox_to_anchor=(1.1,1) )
plt.ylabel('')
plt.show()

# %%
# valores da coluna fase_dia
df['fase_dia'].unique()
# Out:
# array(['Plena Noite', 'Amanhecer', 'Pleno dia', 'Anoitecer'], dtype=object)

# %%
# agrupamento dos registros de acidentes por fase do dia
f_dia = df.groupby(by='fase_dia').count()['id']

# %%
# ordenando os registros do maior para o menor
fase_dia = f_dia.sort_values(ascending=False)
fase_dia
# Out:
# fase_dia
# Pleno dia      4675
# Plena Noite    2722
# Amanhecer       459
# Anoitecer       453
# Name: id, dtype: int64

# %%
# gráfico do percentual de acidentes por fase do dia 
plt.figure(figsize=(7, 5))
fase_dia.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Fase do Dia', pad=10, fontsize=15)
plt.legend(['Pleno dia','Plena Noite','Amanhecer','Anoitecer'],loc='upper right', bbox_to_anchor=(1.2,1))
plt.ylabel('')
plt.show()

# %%
# valores da coluna condicao_metereologica
df['condicao_metereologica'].unique()
# Out:
# array(['Céu Claro', 'Nublado', 'Chuva', 'Ignorado', 'Sol',
#        'Garoa/Chuvisco', 'Vento', 'Nevoeiro/Neblina', 'Granizo'],
#       dtype=object)

# %%
# agrupamento dos registros de acidentes por condição metereologica
tmp = df.groupby(by='condicao_metereologica').count()['id']

# %%
# ordenando os resgistros do maior para o menor
tempo = tmp.sort_values(ascending=False)
tempo
# Out:
# condicao_metereologica
# Céu Claro           4847
# Nublado             1399
# Chuva               1118
# Sol                  604
# Garoa/Chuvisco       149
# Ignorado             133
# Nevoeiro/Neblina      39
# Vento                 19
# Granizo                1
# Name: id, dtype: int64

# %%
# gráfico de acidentes por condição meteorológica
tempo.plot(kind='bar')
plt.xlabel('Condição Meteorológica')
plt.ylabel('Quantidade de Acidentes')
plt.title('Acidentes x Condição Meteorológica')
plt.show()

# %%
# valores da coluna classificacao_acidente
df['classificacao_acidente'].unique()
# Out:
# array(['Sem Vítimas', 'Com Vítimas Fatais', 'Com Vítimas Feridas'],
#       dtype=object)

# %%
# agrupamento dos registros de acidentes por classifição do acidente
cl_acidente = df.groupby(by='classificacao_acidente').count()['id']

# %%
# ordenando os resgistros do maior para o menor
classif_acidente = cl_acidente.sort_values(ascending=False)
classif_acidente
# Out:
# classificacao_acidente
# Com Vítimas Feridas    6482
# Sem Vítimas            1232
# Com Vítimas Fatais      595
# Name: id, dtype: int64

# %%
# gráfico do percentual de acidentes por classificação do acidente
plt.figure(figsize=(7, 5))
classif_acidente.plot.pie(fontsize=14, autopct='%0.0f%%', labeldistance=None, radius=1)
plt.title('Percentual de Acidentes por Classificação do Acidente', pad=10, fontsize=15)
plt.legend(['Com Vítimas Feridas','Sem Vítimas','Com Vítimas Fatais'],loc='upper right', bbox_to_anchor=(1.32,1))
plt.ylabel('')
plt.show()
